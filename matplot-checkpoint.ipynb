# %%
# 載入套件庫並讀入資料
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
import numpy as np

# %%
db = sqlite3.connect('TWStock_2')
#這邊我們挑選一些台灣的代表性股票
stocks_dict = {}
#台積電2330
stocks_dict.update({'tsmc':pd.read_sql(con=db,sql='SELECT * FROM "2330"')})
#台塑化6505
stocks_dict.update({'fpc':pd.read_sql(con=db,sql='SELECT * FROM "6505"')})
#鴻海2317
stocks_dict.update({'foxconn':pd.read_sql(con=db,sql='SELECT * FROM "2317"')})
#中華電2412
stocks_dict.update({'cht':pd.read_sql(con=db,sql='SELECT * FROM "2412"')})
#台塑1301
stocks_dict.update({'fpg':pd.read_sql(con=db,sql='SELECT * FROM "1301"')})
#台化1326
stocks_dict.update({'fcfc':pd.read_sql(con=db,sql='SELECT * FROM "1326"')})
#國泰金2882
stocks_dict.update({'cfh':pd.read_sql(con=db,sql='SELECT * FROM "2882"')})
#南亞1303
stocks_dict.update({'ny':pd.read_sql(con=db,sql='SELECT * FROM "1303"')})
#富邦金2881
stocks_dict.update({'fubon':pd.read_sql(con=db,sql='SELECT * FROM "2881"')})
#大立光3008
stocks_dict.update({'largan':pd.read_sql(con=db,sql='SELECT * FROM "3008"')})

# %%
stocks_dict['largan'].head()
# Out:
#    index 證券名稱       成交股數   成交筆數           成交金額       開盤價       最高價       最低價  \
# 0    659  大立光  1,148,063  1,379  4,219,585,620  3,665.00  3,775.00  3,580.00
# 1    659  大立光    548,150    806  2,030,447,000  3,740.00  3,785.00  3,640.00
# 2    659  大立光    982,236  1,161  3,647,666,400  3,780.00  3,810.00  3,615.00
# 3    659  大立光  2,759,335  2,630  9,394,145,850  3,255.00  3,510.00  3,255.00
# 4    659  大立光  1,207,618  1,121  4,244,921,849  3,550.00  3,555.00  3,470.00
#
#         收盤價 漲跌(+/-)   漲跌價差    最後揭示買價 最後揭示買量    最後揭示賣價 最後揭示賣量    本益比  \
# 0  3,735.00       -   35.0  3,725.00      2  3,735.00      1  19.72
# 1  3,665.00       -   70.0  3,660.00     23  3,670.00      1  19.35
# 2  3,615.00       -   50.0  3,615.00      5  3,620.00      5  19.09
# 3  3,470.00       -  145.0  3,465.00      2  3,470.00     51  18.32
# 4  3,520.00       +   50.0  3,515.00      1  3,520.00     17  18.59
#
#                   Date
# 0  2019-06-03 00:00:00
# 1  2019-06-04 00:00:00
# 2  2019-06-05 00:00:00
# 3  2019-06-06 00:00:00
# 4  2019-06-10 00:00:00

# %%
df_test = stocks_dict['largan'].copy()

# %%
df_test.index = pd.to_datetime(df_test['Date'])

# %%
df_test = df_test[['證券名稱','收盤價']]

# %%
df_test['收盤價'] = df_test['收盤價'].apply(lambda x:x.replace(',',''))

# %%
df_test['收盤價'] = pd.to_numeric(df_test['收盤價'])

# %%
df_test.columns = ['stock_code','close']

# %%
df_test.head()
# Out:
#            stock_code   close
# Date
# 2019-06-03        大立光  3735.0
# 2019-06-04        大立光  3665.0
# 2019-06-05        大立光  3615.0
# 2019-06-06        大立光  3470.0
# 2019-06-10        大立光  3520.0

# %%
'''
在畫圖之前，
我們先整理我們的資料，將每個股票整理成股票名稱與收盤價的表格形式，
其中，因為收盤價被存為字串形式，我們也必須轉為數值形式做進一個的運算
'''
for key in stocks_dict.keys():
    df = stocks_dict[key]
    df.index = df['Date']
    df.index = pd.to_datetime(df.index)
    df = df[['證券名稱','收盤價']]
    df['收盤價'] = pd.to_numeric(df['收盤價'].apply(lambda x:x.replace(',','')),errors='coerce')
    df.columns = ['stock_code','close']
    stocks_dict[key] = df
# Out:
# C:\Users\Weij\AppData\Local\Temp/ipykernel_4888/4051076844.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['收盤價'] = pd.to_numeric(df['收盤價'].apply(lambda x:x.replace(',','')),errors='coerce')

# %%
stocks_dict['tsmc'].head()
# Out:
#            stock_code  close
# Date
# 2019-06-03        台積電  238.0
# 2019-06-04        台積電  233.0
# 2019-06-05        台積電  235.0
# 2019-06-06        台積電  232.0
# 2019-06-10        台積電  240.0

# %%
fig,ax = plt.subplots(3,2,figsize=(20,19)) #圖群尺寸
plt.subplots_adjust(hspace=0.8)    #高度
stocks_dict['largan']['2018-01-01':].plot(ax=ax[0,0])
ax[0,0].set_title('Largan')
stocks_dict['tsmc']['2018-01-01':].plot(ax=ax[0,1])
ax[0,1].set_title('TSMC')
stocks_dict['fubon']['2020-01-01':].plot(ax=ax[1,0])
ax[1,0].set_title('Fubon')
stocks_dict['cfh']['2020-01-01':].plot(ax=ax[1,1])
ax[1,1].set_title('CFH')
stocks_dict['fpg']['2020-01-01':].plot(ax=ax[2,0])
ax[2,0].set_title('FPG')
stocks_dict['fpc']['2020-01-01':].plot(ax=ax[2,1])
ax[2,1].set_title('FPC')
fig.suptitle('Stock Price via time')
plt.show()

# %%
#用TSMC做例子
df = stocks_dict['tsmc'].copy()
df_p = df['2018-01-01':].iloc[:-1,:]
df_a = df['2018-01-01':].iloc[1:,:]
plt.scatter(np.array(df_p['close']),np.array(df_a['close']))
plt.show()
plt.hist([np.array(df['2021-01-01':'2021-09-01']['close']),np.array(df['2021-09-01':]['close'])])
# Out:
# (array([[ 5.,  5., 18., 52., 45., 20.,  8.,  5.,  2.,  1.],
#         [ 0.,  0., 11., 11., 43., 20., 13., 12.,  5.,  2.]]),
#  array([536. , 550.7, 565.4, 580.1, 594.8, 609.5, 624.2, 638.9, 653.6,
#         668.3, 683. ]),
#  <a list of 2 BarContainer objects>)

# %%
df = df['2018-01-01':]
df.head()
# Out:
#            stock_code  close
# Date
# 2019-06-03        台積電  238.0
# 2019-06-04        台積電  233.0
# 2019-06-05        台積電  235.0
# 2019-06-06        台積電  232.0
# 2019-06-10        台積電  240.0

# %%
df['linear return rate'] = df['close'].pct_change()

# %%
df.head()
# Out:
#            stock_code  close  linear return rate
# Date
# 2019-06-03        台積電  238.0                 NaN
# 2019-06-04        台積電  233.0           -0.021008
# 2019-06-05        台積電  235.0            0.008584
# 2019-06-06        台積電  232.0           -0.012766
# 2019-06-10        台積電  240.0            0.034483

# %%
df_lrp = df.iloc[:-1,:]
df_lra = df.iloc[1:,:]
plt.scatter(np.array(df_lrp['linear return rate']),np.array(df_lra['linear return rate']))
plt.show()
